# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as pp

# %%
u_d = pd.read_csv("/content/user_demographics_v1.csv")

# %%
u_d[(u_d.device=='and')&(u_d.age>15)&(u_d.age<30)]
# Out:
#              uid              reg_date device gender country  age
# 0     54030035.0  2017-06-29T00:00:00Z    and      M     USA   19
# 5     64229733.0  2017-05-17T00:00:00Z    and      F     USA   17
# 6     16377492.0  2016-10-16T00:00:00Z    and      M     BRA   20
# 7     36350096.0  2017-04-07T00:00:00Z    and      M     USA   23
# 8     98955454.0  2016-08-11T00:00:00Z    and      M     USA   22
# ...          ...                   ...    ...    ...     ...  ...
# 9982  91337513.0  2017-03-19T00:00:00Z    and      F     USA   18
# 9984  84288329.0  2018-03-02T00:00:00Z    and      F     BRA   18
# 9986  56084248.0  2017-11-28T00:00:00Z    and      F     TUR   18
# 9988  17231199.0  2017-11-10T00:00:00Z    and      F     BRA   21
# 9995  43138741.0  2016-11-23T00:00:00Z    and      M     BRA   16
#
# [3933 rows x 6 columns]

# %%
u_d[(u_d.device=='iOS')&(u_d.age>15)&(u_d.age<30)]
# Out:
#              uid              reg_date device gender country  age
# 1     72574201.0  2018-03-05T00:00:00Z    iOS      F     TUR   22
# 2     64187558.0  2016-02-07T00:00:00Z    iOS      M     USA   16
# 10    99094125.0  2016-02-11T00:00:00Z    iOS      M     USA   16
# 15    58375061.0  2016-06-26T00:00:00Z    iOS      M     USA   25
# 19    89464221.0  2018-01-24T00:00:00Z    iOS      F     USA   21
# ...          ...                   ...    ...    ...     ...  ...
# 9967  69512563.0  2018-02-14T00:00:00Z    iOS      F     USA   25
# 9969  36443173.0  2018-02-09T00:00:00Z    iOS      F     USA   18
# 9983  32143131.0  2017-11-15T00:00:00Z    iOS      M     USA   24
# 9991  59059766.0  2016-03-03T00:00:00Z    iOS      M     USA   23
# 9992  48271199.0  2016-03-10T00:00:00Z    iOS      F     TUR   22
#
# [2866 rows x 6 columns]

# %%
c1 = len ( u_d[(u_d.device=='and')&(u_d.age>15)&(u_d.age<30)] )
c2 = len ( u_d[(u_d.device=='iOS')&(u_d.age>15)&(u_d.age<30)] )

# %%
pp.title ("Pop. b/w 15 - 30")
pp.bar("and",c1)
pp.bar("iOS",c2)
pp.plot()
pp.show()

# %%
u_d[(u_d.device=='iOS')&(u_d.age>=31)&(u_d.age<=45)]
# Out:
#              uid              reg_date device gender country  age
# 17    73480791.0  2017-08-20T00:00:00Z    iOS      M     BRA   45
# 36    43052026.0  2016-10-31T00:00:00Z    iOS      M     DEU   35
# 54    62526257.0  2017-03-17T00:00:00Z    iOS      M     USA   37
# 60    76661000.0  2017-10-18T00:00:00Z    iOS      M     DEU   31
# 90    85383645.0  2017-08-31T00:00:00Z    iOS      M     DEU   33
# ...          ...                   ...    ...    ...     ...  ...
# 9965  24752611.0  2018-02-25T00:00:00Z    iOS      M     BRA   32
# 9972  67293907.0  2017-11-12T00:00:00Z    iOS      F     BRA   32
# 9990  67294307.0  2017-06-07T00:00:00Z    iOS      M     BRA   40
# 9994  51143252.0  2017-12-29T00:00:00Z    iOS      F     USA   32
# 9998  98809962.0  2017-04-08T00:00:00Z    iOS      F     FRA   32
#
# [658 rows x 6 columns]

# %%
u_d[(u_d.device=='and')&(u_d.age>=31)&(u_d.age<=45)]
# Out:
#              uid              reg_date device gender country  age
# 3     92513925.0  2017-05-25T00:00:00Z    and      M     BRA   41
# 9     40461463.0  2017-07-16T00:00:00Z    and      M     BRA   32
# 25    20819344.0  2017-11-09T00:00:00Z    and      M     BRA   33
# 30    24708291.0  2016-01-28T00:00:00Z    and      F     TUR   37
# 87    30120100.0  2017-12-24T00:00:00Z    and      F     DEU   31
# ...          ...                   ...    ...    ...     ...  ...
# 9985  20685810.0  2017-09-01T00:00:00Z    and      F     BRA   37
# 9989  23538800.0  2015-12-19T00:00:00Z    and      M     DEU   38
# 9993  12936762.0  2015-09-03T00:00:00Z    and      F     USA   32
# 9997  92384369.0  2015-08-20T00:00:00Z    and      F     DEU   33
# 9999  82078268.0  2018-02-23T00:00:00Z    and      F     CAN   31
#
# [941 rows x 6 columns]

# %%
c3 = len ( u_d[(u_d.device=='and')&(u_d.age>=31)&(u_d.age<=45)] )
c4 = len ( u_d[(u_d.device=='iOS')&(u_d.age>=31)&(u_d.age<=45)] )

# %%
pp.title ("Pop. b/w 31 - 45")
pp.bar("and",c3)
pp.bar("iOS",c4)
pp.plot()
pp.show()

# %%
pp.title ("Pop. and")
pp.bar("15-30",c1)
pp.bar("31-45",c3)
pp.plot()
pp.show()

# %%
pp.title ("Pop. iOS")
pp.bar("15-30",c2)
pp.bar("31-45",c4)
pp.plot()
pp.show()
