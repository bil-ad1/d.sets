# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as pp

# %%
ecn = pd.read_excel("/content/pk__stz.xlsx")

# %%
ecn.describe()
# Out:
#               Year     Crops   Livestock   Forestry    Fishing  \
# count    22.000000  22.000000  22.000000  22.000000  22.000000
# mean   2010.500000   9.088182  11.975000   0.524091   0.494091
# std       6.493587   1.701279   0.560932   0.173278   0.087269
# min    2000.000000   6.580000  11.150000   0.380000   0.390000
# 25%    2005.250000   7.592500  11.600000   0.412500   0.430000
# 50%    2010.500000   8.955000  11.860000   0.460000   0.470000
# 75%    2015.750000  10.192500  12.135000   0.477500   0.557500
# max    2021.000000  12.860000  13.220000   0.870000   0.700000
#
#        total Agricultural sectors    Mining and Quarrying   Manufacturing   \
# count                   22.000000               22.000000        22.000000
# mean                    22.082273                3.166818        12.976364
# std                      2.427725                0.407295         1.074765
# min                     18.700000                2.380000        10.380000
# ...

# %%
ecn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 24 columns):
#  #   Column                                                      Non-Null Count  Dtype
# ---  ------                                                      --------------  -----
#  0   Year                                                        22 non-null     int64
#  1    Crops                                                      22 non-null     float64
#  2   Livestock                                                   22 non-null     float64
#  3   Forestry                                                    22 non-null     float64
#  4     Fishing                                                   22 non-null     float64
#  5   total Agricultural sectors                                  22 non-null     float64
#  6     Mining and Quarrying                                      22 non-null     float64
# ...

# %%
y_21 = ecn.iloc[21]
print(y_21)
# Out:
# Year                                                              2021
#  Crops                                                            6.87
# Livestock                                                        11.53
# Forestry                                                           0.4
#   Fishing                                                         0.39
# total Agricultural sectors                                       19.19
#   Mining and Quarrying                                            2.38
#  Manufacturing                                                   12.79
#  Large Scale                                                      9.73
# Small Scale                                                       2.12
# Slaughtering                                                      0.94
# Electricity generation & distribution and Gas distribution        1.35
# Construction                                                      2.61
# ...

# %%
y_21_2 = y_21.drop(['GDP']).drop(['Per Capita']).drop('Growth rate').drop('Year')
print(y_21_2)
# Out:
#  Crops                                                         6.87
# Livestock                                                     11.53
# Forestry                                                        0.4
#   Fishing                                                      0.39
# total Agricultural sectors                                    19.19
#   Mining and Quarrying                                         2.38
#  Manufacturing                                                12.79
#  Large Scale                                                   9.73
# Small Scale                                                    2.12
# Slaughtering                                                   0.94
# Electricity generation & distribution and Gas distribution     1.35
# Construction                                                   2.61
#   total Industrial Sectors                                    19.12
# Wholesale & Retail trade                                      18.82
# ...

# %%
pp.pie(y_21_2)
pp.plot()
pp.show()

# %%
ecn.GDP
# Out:
# 0      $82.02B
# 1      $79.48B
# 2      $79.90B
# 3      $91.76B
# 4     $107.76B
# 5     $120.06B
# 6     $137.26B
# 7     $152.39B
# 8     $170.08B
# 9     $168.15B
# 10    $177.17B
# 11    $213.59B
# 12    $224.38B
# 13    $231.22B
# 14    $244.36B
# 15    $270.56B
# 16    $278.65B
# 17    $304.57B
# 18    $314.57B
# 19    $278.22B
# 20    $263.69B
# 21    $280.00B
# Name: GDP, dtype: object

# %%
pp.plot(ecn.Year,ecn.GDP)
pp.plot()
pp.show()
