# %%
import pandas as pd
import matplotlib.pyplot as pp

# %%
u_c = pd.read_csv("/content/drive/MyDrive/d.sets/usedCarsFinal.csv")

# %%
u_c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75899 entries, 0 to 75898
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   name                 75899 non-null  object
#  1   location             75899 non-null  object
#  2   model_year           75899 non-null  int64
#  3   mileage              75899 non-null  object
#  4   engine_type          75899 non-null  object
#  5   transmission         75899 non-null  object
#  6   registered_in        75899 non-null  object
#  7   color                75899 non-null  object
#  8   assembly             75899 non-null  object
#  9   engine_capacity      75899 non-null  object
#  10  body_type            67804 non-null  object
#  11  other_features_list  69353 non-null  object
#  12  url                  75899 non-null  object
#  13  price                74771 non-null  float64
# dtypes: float64(1), int64(1), object(12)
# memory usage: 8.1+ MB

# %%
u_c.name.unique()
# Out:
# array(['Toyota Fortuner Legender  2022',
#        'Toyota Premio X EX Package 1.8 2018',
#        'Honda City Aspire 1.3 i-VTEC 2016', ...,
#        'Mercedes Benz 240 Gd 1983', 'Honda Fit RS 2014',
#        'Toyota Prado RX 2.7 (3-Door) 2002'], dtype=object)

# %%
list(u_c.name.unique())
# Out:
# ['Toyota Fortuner Legender  2022',
#  'Toyota Premio X EX Package 1.8 2018',
#  'Honda City Aspire 1.3 i-VTEC 2016',
#  'Suzuki Bolan VX Euro II 2018',
#  'Suzuki Swift GLX CVT 2022',
#  'Suzuki Alto 2017',
#  'Honda City i-DSI 2006',
#  'Toyota Aqua S 2017',
#  'Toyota Aqua G 2014',
#  'Toyota Corolla SE Limited 1995',
#  'Toyota Vitz F 1.0 2017',
#  'Suzuki Spacia 2014',
#  'Honda City 1.2L M/T 2022',
#  'Honda Civic Oriel 1.8 i-VTEC CVT 2017',
#  'Suzuki Khyber GA 1988',
#  'Daihatsu Cast Activa G SA III 2015',
#  'Toyota Corolla XLi VVTi 2014',
#  'Suzuki Mehran VX Euro II 2012',
#  'Honda Civic EX 1995',
#  'Toyota Prius S LED Edition 1.8 2010',
#  'Honda Vezel Hybrid Z 2016',
#  'Honda Vezel Hybrid Z Honda Sensing  2016',
#  'Honda Vezel Hybrid RS Honda Sensing  2016',
#  'Honda Fit 1.5 Hybrid S Package 2014',
#  'Honda City 1.3 i-VTEC Prosmatec 2014',
#  'Mercedes Benz C Class C180 2012',
#  'Honda Civic Oriel Prosmatec UG 2013',
#  'Toyota Corolla 2020',
# ...

# %%
u_c.location.unique()
# Out:
# array(['I- 8, Islamabad Islamabad', 'Askari 6, Peshawar KPK',
#        'Dhok Sayedan Road, Rawalpindi Punjab', ...,
#        'D-14, Islamabad Islamabad', 'Abdullah Town, Hyderabad Sindh',
#        'Bashir Town, Sahiwal Punjab'], dtype=object)

# %%
list(u_c.location.unique())
# Out:
# ['I- 8, Islamabad Islamabad',
#  'Askari 6, Peshawar KPK',
#  'Dhok Sayedan Road, Rawalpindi Punjab',
#  'Karachi Sindh',
#  'Bani Gala, Islamabad Islamabad',
#  'Cantt, Sialkot Punjab',
#  'Islamabad Islamabad',
#  'DHA City, Lahore Punjab',
#  'Nowshera cantt KPK',
#  'D.H.A, Karachi Sindh',
#  'DHA Defence, Islamabad Islamabad',
#  'A.F.O.H.S, Karachi Sindh',
#  'DHA Defence, Lahore Punjab',
#  'Gulistan-e-Jauhar, Karachi Sindh',
#  'Model Town, Lahore Punjab',
#  'Revenue Society, Lahore Punjab',
#  'Bosan Road, Multan Punjab',
#  'D-17, Islamabad Islamabad',
#  'Maulana Shaukat Ali Road, Lahore Punjab',
#  'Pak Arab Housing Society, Lahore Punjab',
#  'G-11, Islamabad Islamabad',
#  'Lahore Punjab',
#  'Bahria Town, Islamabad Islamabad',
#  'Wapda Town, Gujranwala Punjab',
#  'Scheme 33, Karachi Sindh',
#  'F- 8, Islamabad Islamabad',
#  '204 Chak Road, Faisalabad Punjab',
#  'Sahiwal Punjab',
#  'F-10, Islamabad Islamabad',
#  'G- 9, Islamabad Islamabad',
#  'Sambrial Punjab',
# ...

# %%
u_c.model_year.unique()
# Out:
# array([2022, 2018, 2016, 2017, 2006, 2014, 1995, 1988, 2015, 2012, 2010,
#        2013, 2020, 2019, 1996, 2008, 2007, 2009, 1999, 2021, 2003, 2005,
#        1985, 1986, 1992, 1998, 2004, 2011, 2000, 2002, 1989, 1997, 1990,
#        1991, 1994, 2001, 1982, 1993, 1980, 1981, 1983, 1976, 1979, 1984,
#        1974, 1959, 1987, 1972, 1975, 1963, 1960, 1977, 1978, 1965, 1973,
#        1962, 1970, 1967, 1969, 1952, 1961, 1968, 1947, 1971, 1966, 1951,
#        1964, 1942])
