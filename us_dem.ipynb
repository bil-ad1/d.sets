# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as pp

# %%
u_d = pd.read_csv("/content/user_demographics_v1.csv")

# %%
u_d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   uid       10000 non-null  float64
#  1   reg_date  10000 non-null  object
#  2   device    10000 non-null  object
#  3   gender    10000 non-null  object
#  4   country   10000 non-null  object
#  5   age       10000 non-null  int64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 468.9+ KB

# %%
u_d.describe()
# Out:
#                 uid           age
# count  1.000000e+04  10000.000000
# mean   5.580304e+07     24.399200
# std    2.562174e+07      9.772512
# min    1.111609e+07     15.000000
# 25%    3.392627e+07     17.000000
# 50%    5.627628e+07     21.000000
# 75%    7.786440e+07     28.000000
# max    9.999648e+07     84.000000

# %%
u_d.head(7)
# Out:
#           uid              reg_date device gender country  age
# 0  54030035.0  2017-06-29T00:00:00Z    and      M     USA   19
# 1  72574201.0  2018-03-05T00:00:00Z    iOS      F     TUR   22
# 2  64187558.0  2016-02-07T00:00:00Z    iOS      M     USA   16
# 3  92513925.0  2017-05-25T00:00:00Z    and      M     BRA   41
# 4  99231338.0  2017-03-26T00:00:00Z    iOS      M     FRA   59
# 5  64229733.0  2017-05-17T00:00:00Z    and      F     USA   17
# 6  16377492.0  2016-10-16T00:00:00Z    and      M     BRA   20

# %%
u_d.tail(7)
# Out:
#              uid              reg_date device gender country  age
# 9993  12936762.0  2015-09-03T00:00:00Z    and      F     USA   32
# 9994  51143252.0  2017-12-29T00:00:00Z    iOS      F     USA   32
# 9995  43138741.0  2016-11-23T00:00:00Z    and      M     BRA   16
# 9996  30326568.0  2016-08-21T00:00:00Z    and      M     BRA   15
# 9997  92384369.0  2015-08-20T00:00:00Z    and      F     DEU   33
# 9998  98809962.0  2017-04-08T00:00:00Z    iOS      F     FRA   32
# 9999  82078268.0  2018-02-23T00:00:00Z    and      F     CAN   31

# %%
u_d.device.unique()
# Out:
# array(['and', 'iOS'], dtype=object)

# %%
u_d.country.unique()
# Out:
# array(['USA', 'TUR', 'BRA', 'FRA', 'DEU', 'CAN'], dtype=object)

# %%
u_d[(u_d.country=='USA')&(u_d.gender=='M')&(u_d.device=='and')]
# Out:
#              uid              reg_date device gender country  age
# 0     54030035.0  2017-06-29T00:00:00Z    and      M     USA   19
# 7     36350096.0  2017-04-07T00:00:00Z    and      M     USA   23
# 8     98955454.0  2016-08-11T00:00:00Z    and      M     USA   22
# 11    60943517.0  2018-03-07T00:00:00Z    and      M     USA   22
# 12    13373345.0  2017-09-08T00:00:00Z    and      M     USA   19
# ...          ...                   ...    ...    ...     ...  ...
# 9934  25232480.0  2017-09-12T00:00:00Z    and      M     USA   19
# 9948  45165889.0  2018-01-20T00:00:00Z    and      M     USA   20
# 9949  68854439.0  2015-11-28T00:00:00Z    and      M     USA   15
# 9958  67956289.0  2017-12-18T00:00:00Z    and      M     USA   15
# 9959  69852149.0  2017-05-11T00:00:00Z    and      M     USA   23
#
# [1111 rows x 6 columns]

# %%
u_d[(u_d.country=='USA')&(u_d.gender=='F')&(u_d.device=='and')]
# Out:
#              uid              reg_date device gender country  age
# 5     64229733.0  2017-05-17T00:00:00Z    and      F     USA   17
# 13    89447705.0  2017-11-06T00:00:00Z    and      F     USA   20
# 16    61798397.0  2016-12-29T00:00:00Z    and      F     USA   23
# 29    66770349.0  2018-02-17T00:00:00Z    and      F     USA   16
# 41    74247839.0  2017-04-04T00:00:00Z    and      F     USA   19
# ...          ...                   ...    ...    ...     ...  ...
# 9968  82490013.0  2017-07-19T00:00:00Z    and      F     USA   19
# 9971  19700373.0  2016-11-23T00:00:00Z    and      F     USA   15
# 9978  16015542.0  2018-01-17T00:00:00Z    and      F     USA   20
# 9982  91337513.0  2017-03-19T00:00:00Z    and      F     USA   18
# 9993  12936762.0  2015-09-03T00:00:00Z    and      F     USA   32
#
# [1228 rows x 6 columns]

# %%
u_d[(u_d.country=='USA')&(u_d.gender=='M')&(u_d.device=='iOS')]
# Out:
#              uid              reg_date device gender country  age
# 2     64187558.0  2016-02-07T00:00:00Z    iOS      M     USA   16
# 10    99094125.0  2016-02-11T00:00:00Z    iOS      M     USA   16
# 15    58375061.0  2016-06-26T00:00:00Z    iOS      M     USA   25
# 20    53378171.0  2017-12-02T00:00:00Z    iOS      M     USA   23
# 35    87711484.0  2018-01-19T00:00:00Z    iOS      M     USA   19
# ...          ...                   ...    ...    ...     ...  ...
# 9932  95999470.0  2015-10-05T00:00:00Z    iOS      M     USA   15
# 9933  43232080.0  2018-02-23T00:00:00Z    iOS      M     USA   15
# 9953  87195562.0  2016-05-07T00:00:00Z    iOS      M     USA   23
# 9983  32143131.0  2017-11-15T00:00:00Z    iOS      M     USA   24
# 9991  59059766.0  2016-03-03T00:00:00Z    iOS      M     USA   23
#
# [835 rows x 6 columns]

# %%
u_d[(u_d.country=='USA')&(u_d.gender=='F')&(u_d.device=='iOS')]
# Out:
#              uid              reg_date device gender country  age
# 19    89464221.0  2018-01-24T00:00:00Z    iOS      F     USA   21
# 21    75142313.0  2017-05-30T00:00:00Z    iOS      F     USA   83
# 22    72086031.0  2017-03-28T00:00:00Z    iOS      F     USA   52
# 33    61509814.0  2017-08-18T00:00:00Z    iOS      F     USA   22
# 44    25033821.0  2016-08-19T00:00:00Z    iOS      F     USA   21
# ...          ...                   ...    ...    ...     ...  ...
# 9956  77194676.0  2017-05-13T00:00:00Z    iOS      F     USA   15
# 9962  97989952.0  2016-10-20T00:00:00Z    iOS      F     USA   41
# 9967  69512563.0  2018-02-14T00:00:00Z    iOS      F     USA   25
# 9969  36443173.0  2018-02-09T00:00:00Z    iOS      F     USA   18
# 9994  51143252.0  2017-12-29T00:00:00Z    iOS      F     USA   32
#
# [897 rows x 6 columns]

# %%
a1 = len( u_d[(u_d.country=='USA')&(u_d.gender=='M')&(u_d.device=='and')] )
a2 = len ( u_d[(u_d.country=='USA')&(u_d.gender=='F')&(u_d.device=='and')] )
a3 = len ( u_d[(u_d.country=='USA')&(u_d.gender=='M')&(u_d.device=='iOS')] )
a4 = len ( u_d[(u_d.country=='USA')&(u_d.gender=='F')&(u_d.device=='iOS')] )

# %%
uq = u_d.country.unique()

# %%
pp.bar("US-M-and",a1)
pp.bar("US-F-and",a2)
pp.plot()
pp.show()

# %%
pp.bar("US-M-iOS",a3)
pp.bar("US-F-iOS",a4)
pp.plot()
pp.show()

# %%
u__s = a1,a2,a3,a4
lbs = ['US-M-and','US-F-and','US-M-iOS','US-F-iOS']

# %%
pp.pie(u__s,labels=lbs)
pp.plot()
pp.show()
