# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as pp

# %%
empz = pd.read_csv("/content/emp.csv")

# %%
empz.compensation
# Out:
# 0       64320
# 1       48204
# 2       85812
# 3       49536
# 4       75576
#         ...
# 1949    71388
# 1950    65628
# 1951    77520
# 1952    69780
# 1953    34584
# Name: compensation, Length: 1954, dtype: int64

# %%
empz.work_satisfaction
# Out:
# 0       0.75
# 1       0.85
# 2       0.87
# 3       0.85
# 4       0.80
#         ...
# 1949    0.90
# 1950    0.73
# 1951    0.66
# 1952    0.87
# 1953    0.91
# Name: work_satisfaction, Length: 1954, dtype: float64

# %%
a = empz.compensation
b = empz.work_satisfaction

# %%
pp.scatter(a,b)
pp.plot()
pp.show()

# %%
empz.total_dependents
# Out:
# 0       2
# 1       2
# 2       5
# 3       3
# 4       4
#        ..
# 1949    2
# 1950    5
# 1951    3
# 1952    4
# 1953    5
# Name: total_dependents, Length: 1954, dtype: int64

# %%
c = empz.total_dependents

# %%
pp.scatter(c,a)
pp.plot()
pp.show()

# %%
pp.boxplot(a)
pp.plot()
pp.show()

# %%
pp.boxplot(b)
pp.plot()
pp.show()

# %%
empz.rating.unique()
# Out:
# array(['Above Average', 'Acceptable', 'Below Average', 'Excellent',
#        'Unacceptable'], dtype=object)

# %%
empz[(empz.gender == 'Male') & (empz.rating == 'Acceptable')]
# Out:
#       emp_id    status  location       level gender  emp_age      rating  \
# 3     E10048    Active   Chicago  Specialist   Male    24.55  Acceptable
# 4     E10060    Active   Orlando     Analyst   Male    31.23  Acceptable
# 6     E10065    Active   Chicago     Analyst   Male    24.84  Acceptable
# 9      E1008  Inactive  New York     Analyst   Male    30.14  Acceptable
# 11    E10086  Inactive   Orlando     Analyst   Male    28.14  Acceptable
# ...      ...       ...       ...         ...    ...      ...         ...
# 1942   E9927    Active   Orlando  Specialist   Male    31.20  Acceptable
# 1943   E9934    Active   Orlando  Specialist   Male    26.36  Acceptable
# 1944   E9938  Inactive  New York     Analyst   Male    25.50  Acceptable
# 1951   E9980    Active  New York  Specialist   Male    27.63  Acceptable
# 1952   E9992    Active   Chicago  Specialist   Male    28.34  Acceptable
#
#          mgr_rating  mgr_reportees  mgr_age  ...  date_of_joining  \
# ...

# %%
ram = empz[(empz.gender == 'Male') & (empz.rating == 'Acceptable')]
print(len(ram))
# Out:
# 726

# %%
empz[(empz.gender == 'Female') & (empz.rating == 'Acceptable')]
# Out:
#       emp_id    status  location       level  gender  emp_age      rating  \
# 1     E10025    Active   Chicago     Analyst  Female    25.98  Acceptable
# 2     E10027    Active   Orlando  Specialist  Female    33.40  Acceptable
# 8     E10078    Active  New York     Analyst  Female    29.02  Acceptable
# 14    E10103    Active   Chicago     Analyst  Female    28.45  Acceptable
# 18    E10132  Inactive   Orlando     Analyst  Female    27.83  Acceptable
# ...      ...       ...       ...         ...     ...      ...         ...
# 1915   E9756    Active  New York     Analyst  Female    29.32  Acceptable
# 1924   E9808  Inactive   Chicago     Analyst  Female    25.82  Acceptable
# 1932   E9867  Inactive   Chicago     Analyst  Female    27.67  Acceptable
# 1940   E9904  Inactive   Orlando     Analyst  Female    24.35  Acceptable
# 1953   E9993    Active   Orlando     Analyst  Female    26.25  Acceptable
#
#          mgr_rating  mgr_reportees  mgr_age  ...  date_of_joining  \
# ...

# %%
raf  = empz[(empz.gender == 'Female') & (empz.rating == 'Acceptable')]
print(len(raf))
# Out:
# 342

# %%
g = empz.rating.unique()

# %%
pp.title("Acceptable Ratings")
pp.bar('Males',len(ram),color='g')
pp.bar('Females',len(raf),color='r')
pp.plot()
pp.show()

# %%
empz[(empz.location == 'New York') & (empz.education =='Bachelors') & (empz.marital_status == 'Single')]
# Out:
#       emp_id    status  location       level  gender  emp_age         rating  \
# 0     E10012    Active  New York     Analyst  Female    25.09  Above Average
# 8     E10078    Active  New York     Analyst  Female    29.02     Acceptable
# 9      E1008  Inactive  New York     Analyst    Male    30.14     Acceptable
# 12    E10093  Inactive  New York     Analyst  Female    29.75  Above Average
# 13    E10095  Inactive  New York     Analyst    Male    25.18  Above Average
# ...      ...       ...       ...         ...     ...      ...            ...
# 1935   E9881  Inactive  New York     Analyst    Male    33.22  Below Average
# 1938   E9895    Active  New York     Analyst    Male    32.09     Acceptable
# 1944   E9938  Inactive  New York     Analyst    Male    25.50     Acceptable
# 1948    E996  Inactive  New York     Analyst    Male    26.98  Below Average
# 1951   E9980    Active  New York  Specialist    Male    27.63     Acceptable
#
# ...
