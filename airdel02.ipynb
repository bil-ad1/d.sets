# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as pp

# %%
import seaborn as sb

# %%
f_d = pd.read_csv("/content/drive/MyDrive/d.sets/Flight_delay.csv")

# %%
s_w = f_d[(f_d.Airline =='Southwest Airlines Co.' )]

# %%
s_w.describe()
# Out:
#            DayOfWeek        DepTime        ArrTime     CRSArrTime  \
# count  119048.000000  119048.000000  119048.000000  119048.000000
# mean        4.052559    1644.191923    1676.097204    1711.284272
# std         1.920729     421.024862     570.353956     449.717595
# min         1.000000       1.000000       1.000000       5.000000
# 25%         2.000000    1340.000000    1420.000000    1430.000000
# 50%         4.000000    1717.000000    1815.000000    1805.000000
# 75%         5.000000    2006.000000    2113.000000    2050.000000
# max         7.000000    2400.000000    2400.000000    2355.000000
#
#            FlightNum  ActualElapsedTime  CRSElapsedTime        AirTime  \
# count  119048.000000      119048.000000   119048.000000  119048.000000
# mean     1602.557498         108.772092      108.984275      91.181187
# std      1157.652811          57.522233       56.571763      55.657935
# min         1.000000          30.000000       45.000000       2.000000
# ...

# %%
list(s_w.FlightNum.unique())
# Out:
# [3920,
#  509,
#  1333,
#  675,
#  4,
#  54,
#  623,
#  188,
#  362,
#  422,
#  1056,
#  3244,
#  186,
#  3154,
#  1035,
#  205,
#  3430,
#  1580,
#  2195,
#  23,
#  1574,
#  500,
#  890,
#  1171,
#  302,
#  1079,
#  2021,
#  1018,
#  419,
#  2032,
#  3940,
#  538,
#  2383,
#  219,
#  391,
#  815,
#  1072,
#  2284,
#  2874,
#  1774,
#  2632,
#  564,
#  991,
#  632,
#  706,
#  908,
#  2907,
#  2192,
#  2803,
#  719,
#  3746,
#  1027,
#  1924,
#  3144,
#  82,
#  317,
#  337,
#  354,
#  1061,
#  1928,
#  2367,
#  2896,
#  2382,
#  43,
#  213,
#  411,
#  1004,
#  1405,
#  74,
#  693,
#  2025,
#  2450,
#  2794,
#  3232,
#  3327,
#  223,
#  237,
#  280,
#  900,
#  962,
#  3135,
#  479,
#  875,
#  725,
#  906,
#  1493,
#  2018,
#  2730,
#  3070,
#  156,
#  2354,
#  2550,
#  1285,
#  243,
#  559,
#  668,
#  781,
#  1403,
#  1682,
#  2726,
#  2991,
#  3517,
#  512,
#  416,
#  1509,
#  239,
#  298,
#  709,
#  891,
#  1341,
#  2273,
#  2719,
#  3835,
#  341,
#  708,
#  715,
#  2186,
#  2211,
# ...

# %%
len(list(s_w.FlightNum.unique()))
# Out:
# 3664

# %%
sb.barplot(x='DayOfWeek',y='FlightNum',data=s_w)

# %%
sb.barplot(x='DayOfWeek',y='DepTime',data=s_w)

# %%
sb.scatterplot(x='DepTime',y='ArrTime',data=s_w)

# %%
s_w.corr()
# Out:
#                    DayOfWeek   DepTime   ArrTime  CRSArrTime  FlightNum  \
# DayOfWeek           1.000000  0.049182  0.033574    0.042517   0.004788
# DepTime             0.049182  1.000000  0.421843    0.707192   0.014527
# ArrTime             0.033574  0.421843  1.000000    0.541547   0.008189
# CRSArrTime          0.042517  0.707192  0.541547    1.000000   0.024325
# FlightNum           0.004788  0.014527  0.008189    0.024325   1.000000
# ActualElapsedTime   0.001685 -0.108390 -0.093770   -0.049263   0.048032
# CRSElapsedTime      0.004171 -0.080010 -0.091778   -0.028818   0.052066
# AirTime            -0.000095 -0.096958 -0.089989   -0.040575   0.046474
# ArrDelay            0.013046  0.116902 -0.109202    0.072667  -0.008082
# DepDelay            0.016238  0.155921 -0.105205    0.100102  -0.004014
# Distance            0.003371 -0.076001 -0.107812   -0.033913   0.048077
# TaxiIn              0.013666  0.006237  0.020308    0.022264   0.016941
# ...

# %%
sb.barplot(x='Org_Airport',y='FlightNum',data=s_w)

# %%
sb.displot(x='Org_Airport',y='Dest_Airport',data=s_w)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:88: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   self._figure.tight_layout(*args, **kwargs)
