# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as pp

# %%
empz = pd.read_csv("/content/emp.csv")

# %%
empz[(empz.location == 'New York') & (empz.gender == 'Female')]
# Out:
#       emp_id    status  location       level  gender  emp_age         rating  \
# 0     E10012    Active  New York     Analyst  Female    25.09  Above Average
# 8     E10078    Active  New York     Analyst  Female    29.02     Acceptable
# 12    E10093  Inactive  New York     Analyst  Female    29.75  Above Average
# 25    E10190  Inactive  New York  Specialist  Female    38.68  Above Average
# 35    E10268  Inactive  New York     Analyst  Female    31.41  Below Average
# ...      ...       ...       ...         ...     ...      ...            ...
# 1778   E8883    Active  New York  Specialist  Female    34.32     Acceptable
# 1821   E9080  Inactive  New York     Analyst  Female    25.89     Acceptable
# 1858   E9411    Active  New York  Specialist  Female    30.10     Acceptable
# 1915   E9756    Active  New York     Analyst  Female    29.32     Acceptable
# 1933   E9877  Inactive  New York  Specialist  Female    29.13  Below Average
#
# ...

# %%
a = empz[(empz.location == 'New York') & (empz.gender == 'Female')]
print(len(a))
# Out:
# 76

# %%
empz[(empz.location == 'Chicago') & (empz.gender == 'Female')]
# Out:
#       emp_id    status location    level  gender  emp_age         rating  \
# 1     E10025    Active  Chicago  Analyst  Female    25.98     Acceptable
# 10    E10083    Active  Chicago  Analyst  Female    27.13  Above Average
# 14    E10103    Active  Chicago  Analyst  Female    28.45     Acceptable
# 31    E10240    Active  Chicago  Analyst  Female    27.18  Above Average
# 40     E1031  Inactive  Chicago  Analyst  Female    22.42     Acceptable
# ...      ...       ...      ...      ...     ...      ...            ...
# 1924   E9808  Inactive  Chicago  Analyst  Female    25.82     Acceptable
# 1927   E9835  Inactive  Chicago  Analyst  Female    25.35  Below Average
# 1931   E9866    Active  Chicago  Analyst  Female    36.14  Above Average
# 1932   E9867  Inactive  Chicago  Analyst  Female    27.67     Acceptable
# 1947   E9957    Active  Chicago  Analyst  Female    26.21  Above Average
#
#          mgr_rating  mgr_reportees  mgr_age  ...  date_of_joining  \
# ...

# %%
b= empz[(empz.location == 'Chicago') & (empz.gender == 'Female')]
print(len(b))
# Out:
# 376

# %%
empz[(empz.location == 'Orlando') & (empz.gender == 'Female')]
# Out:
#       emp_id    status location       level  gender  emp_age         rating  \
# 2     E10027    Active  Orlando  Specialist  Female    33.40     Acceptable
# 18    E10132  Inactive  Orlando     Analyst  Female    27.83     Acceptable
# 34    E10262  Inactive  Orlando     Analyst  Female    29.67     Acceptable
# 77     E1053    Active  Orlando  Specialist  Female    34.60     Acceptable
# 78    E10536    Active  Orlando  Specialist  Female    37.79     Acceptable
# ...      ...       ...      ...         ...     ...      ...            ...
# 1871   E9490    Active  Orlando     Analyst  Female    31.06      Excellent
# 1882   E9571    Active  Orlando     Analyst  Female    34.60     Acceptable
# 1889   E9593    Active  Orlando     Analyst  Female    33.73  Below Average
# 1940   E9904  Inactive  Orlando     Analyst  Female    24.35     Acceptable
# 1953   E9993    Active  Orlando     Analyst  Female    26.25     Acceptable
#
# ...

# %%
c = empz[(empz.location == 'Orlando') & (empz.gender == 'Female')]
print(len(c))
# Out:
# 153

# %%
d = empz.location.unique()

# %%
pp.bar(d[0],len(a),color='b')
pp.bar(d[1],len(b),color='g')
pp.bar(d[2],len(c),color='r')
pp.plot()
pp.show()
