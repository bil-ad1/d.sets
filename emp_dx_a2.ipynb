# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as pp

# %%
empz = pd.read_csv("/content/emp.csv")

# %%
empz.location.unique()
# Out:
# array(['New York', 'Chicago', 'Orlando'], dtype=object)

# %%
empz[(empz.location == 'New York') & (empz.education == 'Bachelors')]
# Out:
#       emp_id    status  location       level  gender  emp_age         rating  \
# 0     E10012    Active  New York     Analyst  Female    25.09  Above Average
# 8     E10078    Active  New York     Analyst  Female    29.02     Acceptable
# 9      E1008  Inactive  New York     Analyst    Male    30.14     Acceptable
# 12    E10093  Inactive  New York     Analyst  Female    29.75  Above Average
# 13    E10095  Inactive  New York     Analyst    Male    25.18  Above Average
# ...      ...       ...       ...         ...     ...      ...            ...
# 1935   E9881  Inactive  New York     Analyst    Male    33.22  Below Average
# 1938   E9895    Active  New York     Analyst    Male    32.09     Acceptable
# 1944   E9938  Inactive  New York     Analyst    Male    25.50     Acceptable
# 1948    E996  Inactive  New York     Analyst    Male    26.98  Below Average
# 1951   E9980    Active  New York  Specialist    Male    27.63     Acceptable
#
# ...

# %%
a1 = empz[(empz.location == 'New York') & (empz.education == 'Bachelors')]
print(len(a1))
# Out:
# 306

# %%
empz[(empz.location == 'New York') & (empz.education == 'Masters')]
# Out:
#       emp_id    status  location       level  gender  emp_age         rating  \
# 138    E1097  Inactive  New York     Analyst    Male    25.29     Acceptable
# 236   E11524  Inactive  New York     Analyst  Female    27.73     Acceptable
# 331   E12147    Active  New York  Specialist    Male    34.47  Above Average
# 399   E12531  Inactive  New York     Analyst    Male    28.27     Acceptable
# 559   E13490  Inactive  New York     Analyst  Female    24.10  Below Average
# 632    E1498  Inactive  New York     Analyst  Female    28.78  Below Average
# 697     E187    Active  New York  Specialist    Male    32.47  Above Average
# 793    E2522  Inactive  New York     Analyst    Male    30.10     Acceptable
# 846    E2836    Active  New York  Specialist    Male    31.39  Above Average
# 875    E3058  Inactive  New York     Analyst    Male    39.59   Unacceptable
# 892    E3180  Inactive  New York     Analyst    Male    33.55     Acceptable
# ...

# %%
a2 = empz[(empz.location == 'New York') & (empz.education == 'Masters')]
print(len(a2))
# Out:
# 20

# %%
a1_2 = np.array(["M w B","M w M"])

# %%
pp.bar(a1_2[0],len(a1),color='g')
pp.bar(a1_2[1],len(a2),color='b')
pp.plot()
pp.show()
