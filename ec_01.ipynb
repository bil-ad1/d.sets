# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as pp
import seaborn as sb

# %%
e_c = pd.read_csv("/content/drive/MyDrive/d.sets/Pakistan Largest Ecommerce Dataset.csv")
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (7) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
e_c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 584524 entries, 0 to 584523
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   item_id                584524 non-null  int64
#  1   status                 584509 non-null  object
#  2   created_at             584524 non-null  object
#  3   sku                    584504 non-null  object
#  4   price                  584524 non-null  float64
#  5   qty_ordered            584524 non-null  int64
#  6   grand_total            584524 non-null  float64
#  7   increment_id           584524 non-null  object
#  8   category_name_1        584360 non-null  object
#  9   sales_commission_code  447349 non-null  object
#  10  discount_amount        584524 non-null  float64
#  11  payment_method         584524 non-null  object
#  12  Working Date           584524 non-null  object
#  13  BI Status              584524 non-null  object
# ...

# %%
e_c.category_name_1.unique()
# Out:
# array(["Women's Fashion", 'Beauty & Grooming', 'Soghaat',
#        'Mobiles & Tablets', 'Appliances', 'Home & Living',
#        "Men's Fashion", 'Kids & Baby', '\\N', 'Others', 'Entertainment',
#        'Computing', 'Superstore', 'Health & Sports', 'Books',
#        'School & Education', nan], dtype=object)

# %%
e_c.Year.unique()
# Out:
# array([2016, 2017, 2018])

# %%
e_c.payment_method.unique()
# Out:
# array(['cod', 'ublcreditcard', 'mygateway', 'customercredit',
#        'cashatdoorstep', 'mcblite', 'internetbanking', 'marketingexpense',
#        'productcredit', 'financesettlement', 'Payaxis', 'jazzvoucher',
#        'jazzwallet', 'Easypay', 'Easypay_MA', 'easypay_voucher',
#        'bankalfalah', 'apg'], dtype=object)

# %%
list(e_c.sku.unique())
# Out:
# ['kreations_YI 06-L',
#  'kcc_Buy 2 Frey Air Freshener & Get 1 Kasual Body Spray Free',
#  'Ego_UP0017-999-MR0',
#  'kcc_krone deal',
#  'BK7010400AG',
#  'UK_Namkino All In One 200 Gms',
#  'UK_Namkino Mix Nimco 400 Gms',
#  'Apple iPhone 6S 64GB',
#  'GFC_Pedestal Myga Cross Base (Special Guard) 24"',
#  'BK1070200PL',
#  'BK1130200CF',
#  'kcc_Sultanat',
#  'kcc_glamour deal',
#  'Assetmen_MD-346-M',
#  'cr_DATES WITH CASHEW-400 GM',
#  'UK_Gift Box Mix Dry Fruit Sweets 500 Gms',
#  'itter_AB 1199',
#  'RL_B005',
#  'bed&rest_S7',
#  'L&L_LLHLE8224S',
#  'J&J_JJR-4',
#  'J&J_JJR-20',
#  'D Lend a Helping Hand',
#  'Mochika_M0001112-12',
#  'Mochika_M0001112-8',
#  'SKMT_Blood Test',
#  'SKMT_Medicine',
#  'sputnik_701/5-11',
#  'Ctees-Black Zip- Up Hoodie-XL',
#  'Samsung Galaxy J5',
#  'Veet_4',
#  'RS_Gulab jaman Tin',
#  'cr_PEANUT SALTY-200 GM',
#  'Oriflame_21557',
#  'JBS_TAT-128',
#  'Ajmery_BRR-590-M',
#  'HOS_GUCFW75',
#  'Lexon_LL116B-Blue',
# ...

# %%
list ( e_c[(e_c.category_name_1=='Appliances')].sku.unique() )
# Out:
# ['GFC_Pedestal Myga Cross Base (Special Guard) 24"',
#  'Orient_OR-6057 GX LGFD LV',
#  'jackpot_JP-7999',
#  'anex_2028',
#  'sstop_Mini AIr Conditioner',
#  'mm_AG-1038c',
#  'mitsubishi_1.5 ton SRC 18CLK',
#  'gree_12CZ8',
#  'dawlance_Health Zone Plus 30 - 1.5 Ton Air Conditioner',
#  'Rajesh_RAJ61',
#  'osaka_3.5W LED BULB',
#  'b&d_Citrus Juicer CJ650   ',
#  'mitsubhisi_1.0 Ton - SRK-13CMK',
#  'jackpot_JP-902',
#  'Royal_Energy saver Fan 56 New Model',
#  'dawlance_Refrigerator 9170WB Energy Saver',
#  'Rajesh_White Wax Vac Ear Cleaner',
#  'west point_WF-306',
#  'alpina_Popcorn Maker SF-2608',
#  'Gree_24CZ8',
#  'philips_HD8323/01',
#  'dawlance_Health Zone Plus 15 - 1 Ton Air Conditioner',
#  'mm_AG-3017',
#  'mm_AG-2049',
#  'jackpot_JP-14',
#  'closecomfort_PC8',
#  'Infinix Hot Note X551-1GB-Gold-Nationwide Delivery',
#  'R&I_eIcon Series 12000BTU',
#  'Elite_EDF-89R',
#  'Dawlance_DW-540 AF',
#  'Rajesh_RAJ57',
#  'dawlance_Reddish DW-115CHZ White',
# ...
