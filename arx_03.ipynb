# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as pp

# %%
import seaborn as sb

# %%
arz = pd.read_csv("/content/drive/MyDrive/d.sets/Airlines.csv")

# %%
d__1 = arz[(arz.Delay==1)]

# %%
d__1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 240264 entries, 0 to 539382
# Data columns (total 9 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   id           240264 non-null  int64
#  1   Airline      240264 non-null  object
#  2   Flight       240264 non-null  int64
#  3   AirportFrom  240264 non-null  object
#  4   AirportTo    240264 non-null  object
#  5   DayOfWeek    240264 non-null  int64
#  6   Time         240264 non-null  int64
#  7   Length       240264 non-null  int64
#  8   Delay        240264 non-null  int64
# dtypes: int64(6), object(3)
# memory usage: 18.3+ MB

# %%
d__1.head()
# Out:
#    id Airline  Flight AirportFrom AirportTo  DayOfWeek  Time  Length  Delay
# 0   1      CO     269         SFO       IAH          3    15     205      1
# 1   2      US    1558         PHX       CLT          3    15     222      1
# 2   3      AA    2400         LAX       DFW          3    20     165      1
# 3   4      AA    2466         SFO       DFW          3    20     195      1
# 5   6      CO    1094         LAX       IAH          3    30     181      1

# %%
d__1.tail()
# Out:
#             id Airline  Flight AirportFrom AirportTo  DayOfWeek  Time  Length  \
# 539373  539374      B6     480         LAX       BOS          5  1435     320
# 539376  539377      B6     717         JFK       SJU          5  1439     220
# 539377  539378      B6     739         JFK       PSE          5  1439     223
# 539381  539382      UA      78         HNL       SFO          5  1439     313
# 539382  539383      US    1442         LAX       PHL          5  1439     301
#
#         Delay
# 539373      1
# 539376      1
# 539377      1
# 539381      1
# 539382      1

# %%
d__1.describe()
# Out:
#                   id         Flight      DayOfWeek           Time  \
# count  240264.000000  240264.000000  240264.000000  240264.000000
# mean   293973.333700    2321.413508       3.873697     849.405308
# std    152307.483086    2017.368082       1.922004     263.472137
# min         1.000000       1.000000       1.000000      10.000000
# 25%    173660.500000     701.000000       2.000000     640.000000
# 50%    303136.500000    1695.000000       4.000000     860.000000
# 75%    425796.250000    3408.000000       5.000000    1060.000000
# max    539383.000000    7814.000000       7.000000    1439.000000
#
#               Length     Delay
# count  240264.000000  240264.0
# mean      135.369697       1.0
# std        71.723475       0.0
# min         0.000000       1.0
# 25%        82.000000       1.0
# 50%       118.000000       1.0
# 75%       166.000000       1.0
# max       655.000000       1.0

# %%
d__1.corr()
# Out:
#                  id    Flight  DayOfWeek      Time    Length  Delay
# id         1.000000 -0.016273  -0.060178  0.007654  0.012463    NaN
# Flight    -0.016273  1.000000   0.006053 -0.014613 -0.319470    NaN
# DayOfWeek -0.060178  0.006053   1.000000  0.007249  0.011266    NaN
# Time       0.007654 -0.014613   0.007249  1.000000 -0.045439    NaN
# Length     0.012463 -0.319470   0.011266 -0.045439  1.000000    NaN
# Delay           NaN       NaN        NaN       NaN       NaN    NaN

# %%
sb.barplot(x='Airline',y='Delay',data=d__1)

# %%
sb.histplot(x='Airline',y='Delay',data=d__1)

# %%
co = d__1[(d__1.Airline=='CO')]
us = d__1[(d__1.Airline=='US')]
aa = d__1[(d__1.Airline=='AA')]
ax = d__1[(d__1.Airline=='AS')]
dl = d__1[(d__1.Airline=='DL')]
b6 = d__1[(d__1.Airline=='B6')]
ha = d__1[(d__1.Airline=='HA')]
oo = d__1[(d__1.Airline=='OO')]
e9 = d__1[(d__1.Airline=='9E')]
oh = d__1[(d__1.Airline=='OH')]
ev = d__1[(d__1.Airline=='EV')]
xe = d__1[(d__1.Airline=='XE')]
yv = d__1[(d__1.Airline=='YV')]
ua = d__1[(d__1.Airline=='UA')]
mq = d__1[(d__1.Airline=='MQ')]
fl = d__1[(d__1.Airline=='FL')]
f9 = d__1[(d__1.Airline=='F9')]
wn = d__1[(d__1.Airline=='WN')]

# %%
pp.title('Delay Analysis')
pp.bar('CO',len(co))
pp.bar('US',len(us))
pp.bar('AA',len(aa))
pp.bar('AS',len(ax))
pp.bar('DL',len(dl))
pp.bar('B6',len(b6))
pp.bar('HA',len(ha))
pp.bar('OO',len(oo))
pp.bar('9E',len(e9))
pp.bar('OH',len(oh))
pp.bar('EV',len(ev))
pp.bar('XE',len(xe))
pp.bar('YV',len(yv))
pp.bar('UA',len(ua))
pp.bar('MQ',len(mq))
pp.bar('FL',len(fl))
pp.bar('F9',len(f9))
pp.bar('WN',len(wn))
pp.bar('US',len(us))
pp.bar('US',len(us))
# Out:
# <BarContainer object of 1 artists>

# %%
dl[dl.AirportFrom=='ATL']
# Out:
#             id Airline  Flight AirportFrom AirportTo  DayOfWeek  Time  Length  \
# 1227      1228      DL    1486         ATL       LGA          3   400     127
# 2070      2071      DL    1105         ATL       SLC          3   445     253
# 2078      2079      DL    1694         ATL       PHL          3   445     120
# 2082      2083      DL    2012         ATL       ORD          3   445     127
# 2170      2171      DL    1176         ATL       CLT          3   450      75
# ...        ...     ...     ...         ...       ...        ...   ...     ...
# 539140  539141      DL    1038         ATL       IND          5  1315     101
# 539142  539143      DL    1603         ATL       LAS          5  1315     286
# 539155  539156      DL    1229         ATL       PBI          5  1316     110
# 539298  539299      DL    2950         ATL       RDU          5  1365      79
# 539299  539300      DL    2969         ATL       MCO          5  1365      86
#
#         Delay
# 1227        1
# ...

# %%
dl[dl.AirportTo=='ATL']
# Out:
#             id Airline  Flight AirportFrom AirportTo  DayOfWeek  Time  Length  \
# 11          12      DL    1646         PHX       ATL          3    50     212
# 126        127      DL    1112         PIT       ATL          3   345     131
# 132        133      DL    2939         DCA       ATL          3   345     120
# 153        154      DL    1248         IAH       ATL          3   350     130
# 155        156      DL    2387         MKE       ATL          3   350     129
# ...        ...     ...     ...         ...       ...        ...   ...     ...
# 537797  537798      DL    1431         CVG       ATL          5  1135      99
# 538073  538074      DL      73         JFK       ATL          5  1155     175
# 538226  538227      DL    1237         DTW       ATL          5  1170     136
# 539331  539332      DL    1714         ONT       ATL          5  1380     240
# 539344  539345      DL    2102         LAS       ATL          5  1400     220
#
#         Delay
# 11          1
# ...

# %%
dl[dl.AirportFrom=='BOS']
# Out:
#             id Airline  Flight AirportFrom AirportTo  DayOfWeek  Time  Length  \
# 287        288      DL    2525         BOS       MSP          3   360     210
# 1014      1015      DL    1209         BOS       SLC          3   390     342
# 2174      2175      DL    1375         BOS       LGA          3   450      76
# 2927      2928      DL    2699         BOS       MSP          3   490     202
# 6664      6665      DL    2725         BOS       MSP          3   686     194
# ...        ...     ...     ...         ...       ...        ...   ...     ...
# 530521  530522      DL    2725         BOS       MSP          5   688     197
# 532735  532736      DL    2001         BOS       ATL          5   810     178
# 533563  533564      DL    2925         BOS       MSP          5   858     200
# 535307  535308      DL    2101         BOS       ATL          5   960     183
# 537551  537552      DL    2301         BOS       ATL          5  1110     186
#
#         Delay
# 287         1
# ...

# %%
dl[dl.AirportTo=='BOS']
# Out:
#             id Airline  Flight AirportFrom AirportTo  DayOfWeek  Time  Length  \
# 2173      2174      DL    1372         LGA       BOS          3   450      66
# 4822      4823      DL    1922         DTW       BOS          3   590     112
# 6243      6244      DL    2532         MCO       BOS          3   665     172
# 8345      8346      DL    1492         MSP       BOS          3   780     170
# 9404      9405      DL    1422         DTW       BOS          3   835     113
# ...        ...     ...     ...         ...       ...        ...   ...     ...
# 534474  534475      DL    1400         ATL       BOS          5   906     153
# 535561  535562      DL    2300         ATL       BOS          5   975     151
# 536953  536954      DL    2400         ATL       BOS          5  1065     153
# 537885  537886      DL    2022         MSP       BOS          5  1140     166
# 538341  538342      DL    1522         DTW       BOS          5  1180     116
#
#         Delay
# 2173        1
# ...

# %%
dl[(dl.AirportTo=='BOS')&(dl.AirportFrom=='ATL')]
# Out:
#             id Airline  Flight AirportFrom AirportTo  DayOfWeek  Time  Length  \
# 17085    17086      DL     412         ATL       BOS          3  1290     148
# 30010    30011      DL    2300         ATL       BOS          4   980     154
# 33179    33180      DL      47         ATL       BOS          4  1145     154
# 35105    35106      DL     412         ATL       BOS          4  1290     148
# 56951    56952      DL    1700         ATL       BOS          6   525     160
# ...        ...     ...     ...         ...       ...        ...   ...     ...
# 515248  515249      DL    2100         ATL       BOS          4   830     150
# 517986  517987      DL    2300         ATL       BOS          4   975     151
# 534474  534475      DL    1400         ATL       BOS          5   906     153
# 535561  535562      DL    2300         ATL       BOS          5   975     151
# 536953  536954      DL    2400         ATL       BOS          5  1065     153
#
#         Delay
# 17085       1
# ...

# %%
dl[(dl.AirportFrom=='BOS')&(dl.AirportTo=='ATL')]
# Out:
#             id Airline  Flight AirportFrom AirportTo  DayOfWeek  Time  Length  \
# 7587      7588      DL      46         BOS       ATL          3   735     176
# 8939      8940      DL    2001         BOS       ATL          3   810     173
# 11673    11674      DL    2101         BOS       ATL          3   960     183
# 14573    14574      DL    2301         BOS       ATL          3  1110     186
# 28230    28231      DL    1601         BOS       ATL          4   885     174
# ...        ...     ...     ...         ...       ...        ...   ...     ...
# 520647  520648      DL    2301         BOS       ATL          4  1110     186
# 528514  528515      DL    1701         BOS       ATL          5   585     179
# 532735  532736      DL    2001         BOS       ATL          5   810     178
# 535307  535308      DL    2101         BOS       ATL          5   960     183
# 537551  537552      DL    2301         BOS       ATL          5  1110     186
#
#         Delay
# 7587        1
# ...

# %%
pp.title('Delay b/w BOS & ATL of DL')
pp.bar('B-A',158)
pp.bar('A-B',136)
# Out:
# <BarContainer object of 1 artists>

# %%
list(dl.Flight.unique())
# Out:
# [2606,
#  1646,
#  1112,
#  2939,
#  1248,
#  2387,
#  1831,
#  2280,
#  2437,
#  2525,
#  2782,
#  2154,
#  1212,
#  2513,
#  1241,
#  1260,
#  2283,
#  1209,
#  1254,
#  1871,
#  1981,
#  2061,
#  2724,
#  2946,
#  1040,
#  1071,
#  1486,
#  519,
#  1922,
#  2166,
#  2053,
#  2449,
#  2648,
#  2555,
#  1004,
#  1232,
#  1235,
#  1477,
#  1498,
#  1996,
#  210,
#  2120,
#  2276,
#  2452,
#  2599,
#  2610,
#  2663,
#  2787,
#  2927,
#  2944,
#  2952,
#  749,
#  1205,
#  2366,
#  301,
#  1179,
#  1725,
#  2188,
#  2788,
#  2965,
#  1105,
#  1617,
#  1694,
#  2012,
#  2036,
#  2458,
#  2968,
#  1176,
#  1303,
#  1372,
#  1375,
#  1663,
#  2190,
#  2266,
#  2420,
#  1878,
#  1079,
#  2099,
#  55,
#  2892,
#  2260,
#  2861,
#  16,
#  1904,
#  1492,
#  2232,
#  2739,
#  1440,
#  1524,
#  2348,
#  2662,
#  1499,
#  2073,
#  2699,
#  1005,
#  1581,
#  2510,
#  1433,
#  1517,
#  1555,
#  1605,
#  2143,
#  2230,
#  258,
#  2896,
#  1227,
#  2585,
#  1857,
#  126,
#  1301,
#  1452,
#  1825,
# ...
