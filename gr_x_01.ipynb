# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as pp

# %%
g_x = pd.read_csv("/content/train_v9rqX0R.csv")

# %%
g_x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
# list(g_x.Item_Identifier.unique())

# %%
g_x.Item_Type.unique()
# Out:
# array(['Dairy', 'Soft Drinks', 'Meat', 'Fruits and Vegetables',
#        'Household', 'Baking Goods', 'Snack Foods', 'Frozen Foods',
#        'Breakfast', 'Health and Hygiene', 'Hard Drinks', 'Canned',
#        'Breads', 'Starchy Foods', 'Others', 'Seafood'], dtype=object)

# %%
# g_x.Outlet_Identifier.unique()

# %%
g_x.Outlet_Size.unique()
# Out:
# array(['Medium', nan, 'High', 'Small'], dtype=object)

# %%
g_x.Outlet_Type.unique()
# Out:
# array(['Supermarket Type1', 'Supermarket Type2', 'Grocery Store',
#        'Supermarket Type3'], dtype=object)

# %%
g_x.Outlet_Location_Type.unique()
# Out:
# array(['Tier 1', 'Tier 3', 'Tier 2'], dtype=object)

# %%
g_x[(g_x.Item_Type =='Dairy' )&(g_x.Outlet_Size=='Small')]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility Item_Type  \
# 11             FDA03       18.500          Regular         0.045464     Dairy
# 19             FDU02       13.350          Low Fat         0.102492     Dairy
# 40             FDU02       13.350          Low Fat         0.102512     Dairy
# 49             FDS02          NaN          Regular         0.255395     Dairy
# 110            FDD03       13.300          Low Fat         0.079806     Dairy
# ...              ...          ...              ...              ...       ...
# 8211           FDZ15       13.100          Low Fat         0.000000     Dairy
# 8386           FDB51        6.920          Low Fat         0.038454     Dairy
# 8404           DRH39          NaN          low fat         0.000000     Dairy
# 8424           FDC39        7.405          Low Fat         0.159165     Dairy
# 8457           FDY50        5.800          Low Fat         0.130931     Dairy
#
# ...

# %%
g_x[(g_x.Item_Type =='Frozen Foods' )&(g_x.Outlet_Size=='High')]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 51             FDM40       10.195          Low Fat         0.159804
# 159            FDQ28       14.000          Regular         0.060377
# 266            FDG29       17.600          Low Fat         0.056245
# 269            FDM28       15.700          Low Fat         0.045166
# 314            FDB29       16.700          Regular         0.052368
# ...              ...          ...              ...              ...
# 8022           FDZ16       16.850          Regular         0.159723
# 8257           FDA52       16.200          Regular         0.128315
# 8333           FDC41       15.600          Low Fat         0.116816
# 8354           FDO52       11.600          Regular         0.077100
# 8389           FDJ40       13.600          Regular         0.049548
#
#          Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 51    Frozen Foods  141.5154            OUT013                       1987
# ...
